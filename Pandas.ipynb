# %% [markdown]
# <h1 style="color:brown" align="center"> <b>Pandas: Introduction </b></h1>

# %% [markdown]
# # **Introduction to Pandas**
# * **It is often said that 80% of data analysis activity is spent on the data cleaning and preparation of our data. To get the grip over this activity, this section will focus on a small but important aspect of data manipulation and cleaning with Pandas.**

# %% [markdown]
# ## **Inbuilt Data Structure in Pandas**
# **There are two types of data structures are there in Pandas -** <br>
#
# * **Series -** It is one-dimensional labeled array capable of holding any data type (integer, string, float, Python objects etc.) of data. The axis is collectively referred to as index. <br>
#
# * **Data Frame -** It is a two-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL Table or a Series of objects <br>

# %% [markdown]
# ## **Series Data Structure**
# **pandas.core.series.Series(data, index, dtype, copy)** <br>
# * **data -** data takes various forms like ndarray, list, constants, dictionary etc. <br>
# * **index -** it is unique and hashable for easy identification. <br>
# * **dtype -** it is for data type. <br>
# * **copy -** copy data, and its default value is False. It only affects for Series or one dimensional ndarray inputs. <br>

# %%
# !pip install numpy
# !pip install pandas

# %%
# importing required modules
import numpy as np
import pandas as pd

# %%
# creating empty series
s = pd.Series()
print(s, type(s))
# Out:
# Series([], dtype: object) <class 'pandas.core.series.Series'>

# %%
# to ignore warning messages (optional)
import warnings
warnings.filterwarnings('ignore')

# %%
# creating series from ndarray
arr_data = np.array(['apple', 'banana', 'pineapple', 'coconut'])
s = pd.Series(data = arr_data)
print(s)
print(type(s))
print(s[0], s[3])
print(s[1:3])
# Out:
# 0        apple
# 1       banana
# 2    pineapple
# 3      coconut
# dtype: object
# <class 'pandas.core.series.Series'>
# apple coconut
# 1       banana
# 2    pineapple
# dtype: object

# %%
# creating series from ndarray
arr_data = np.array(['apple', 'banana', 'pineapple', 'coconut'])
my_index = ['fruit-1', 'fruit-2', 'fruit-3', 'fruit-4']
s = pd.Series(data = arr_data, index = my_index)
print(s)
print(type(s))
print(s['fruit-1'], s[0], s['fruit-3'], s[2])
s[0] = 'orange'
s['fruit-3'] = "guava"
print(s)
# Out:
# fruit-1        apple
# fruit-2       banana
# fruit-3    pineapple
# fruit-4      coconut
# dtype: object
# <class 'pandas.core.series.Series'>
# apple apple pineapple pineapple
# fruit-1     orange
# fruit-2     banana
# fruit-3      guava
# fruit-4    coconut
# dtype: object

# %%
arr_data = np.array([100, 200, 300, 400])
s = pd.Series(arr_data, copy = False)
s[0] = 999; arr_data[2] = 888
print(arr_data)
print(s)
# Out:
# [999 200 888 400]
# 0    999
# 1    200
# 2    888
# 3    400
# dtype: int32

# %%
arr_data = np.array([100, 200, 300, 400])
s = pd.Series(arr_data, copy = True)
s[0] = 999; arr_data[2] = 888
print(arr_data)
print(s)
# Out:
# [100 200 888 400]
# 0    999
# 1    200
# 2    300
# 3    400
# dtype: int32

# %%
# creating series from ndarray
arr_data = np.array(['apple', 'banana', 'pineapple', 'coconut'])
my_index = ['fruit-1', 'fruit-2', 'fruit-1', 'fruit-2']
s = pd.Series(data = arr_data, index = my_index)
print(s)
print(type(s))
print(s['fruit-1'])
print(s['fruit-2'])
# Out:
# fruit-1        apple
# fruit-2       banana
# fruit-1    pineapple
# fruit-2      coconut
# dtype: object
# <class 'pandas.core.series.Series'>
# fruit-1        apple
# fruit-1    pineapple
# dtype: object
# fruit-2     banana
# fruit-2    coconut
# dtype: object

# %%
# creating series from dictionary
dict_data = {'apple':100, 'banana':230, 'kiwi':450, 'lemon':345}
print(dict_data)
s = pd.Series(dict_data)
print(s)
s = pd.Series(dict_data, index = ['banana', 'apple', 'kiwi', 'lime', 'coconut'])
print(s)
# Out:
# {'apple': 100, 'banana': 230, 'kiwi': 450, 'lemon': 345}
# apple     100
# banana    230
# kiwi      450
# lemon     345
# dtype: int64
# banana     230.0
# apple      100.0
# kiwi       450.0
# lime         NaN
# coconut      NaN
# dtype: float64

# %%
# creating series from a scalar
s = pd.Series(500, index = [100, 104, 102, 106])
print(s)
# Out:
# 100    500
# 104    500
# 102    500
# 106    500
# dtype: int64

# %%
# create series from a list
s = pd.Series(data = [100, 300, 200, 400], index = ['red', 'green', 'blue', 'black'])
print(s)
# Out:
# red      100
# green    300
# blue     200
# black    400
# dtype: int64

# %% [markdown]
# ## DataFrame Data Structure

# %% [markdown]
# ### Create DataFrame

# %%
user_data = [['alice',19,'F','student'],['john',26,'M','student']]
user_columns = ['name', 'age', 'gender', 'job']
user1 = pd.DataFrame(data = user_data)
user1
# Out:
#        0   1  2        3
# 0  alice  19  F  student
# 1   john  26  M  student

# %%
user_data = [['alice',19,'F','student'],['john',26,'M','student']]
user_columns = ['name', 'age', 'gender', 'job']
user1 = pd.DataFrame(data = user_data, columns = user_columns)
user1
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student

# %%
user_data = dict(name=['eric','paul'], age=[22,58], gender=['M','F'], job=['student','manager'])
print(user_data)
user2 = pd.DataFrame(data = user_data)
user2
# Out:
# {'name': ['eric', 'paul'], 'age': [22, 58], 'gender': ['M', 'F'], 'job': ['student', 'manager']}
#    name  age gender      job
# 0  eric   22      M  student
# 1  paul   58      F  manager

# %%
user_data = {'name':['peter','julie'], 'age':[33,44], 'gender':['M','F'], 'job':['engineer','scientist']}
print(user_data)
user3 = pd.DataFrame(data = user_data)
user3
# Out:
# {'name': ['peter', 'julie'], 'age': [33, 44], 'gender': ['M', 'F'], 'job': ['engineer', 'scientist']}
#     name  age gender        job
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %% [markdown]
# ### Concatenate DataFrame

# %%
users = pd.concat([user1, user2, user3])
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 0   eric   22      M    student
# 1   paul   58      F    manager
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %%
users = pd.concat([user1, user2, user3], ignore_index=True)
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %% [markdown]
# ### DataFrame to NumPy ndarray

# %%
arr_data = users.to_numpy()
print(arr_data)
arr_data = np.array(users)
print(arr_data)
# Out:
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]

# %% [markdown]
# ### Join DataFrames

# %%
dict_data = dict(name=['alice','john','eric','julie','anderson'], height=[165,180,175,169,180])
user4 = pd.DataFrame(data = dict_data)
user4
# Out:
#        name  height
# 0     alice     165
# 1      john     180
# 2      eric     175
# 3     julie     169
# 4  anderson     180

# %% [markdown]
# ![image.png](attachment:fd609aba-37db-418d-a667-858e05215bd5.png)

# %%
# inner join operation: only matching rows
merge_inner = pd.merge(users, user4, on='name', how='inner')
merge_inner
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student     165
# 1   john   26      M    student     180
# 2   eric   22      M    student     175
# 3  julie   44      F  scientist     169

# %%
merge_inner = pd.merge(users, user4, on='name')
merge_inner
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student     165
# 1   john   26      M    student     180
# 2   eric   22      M    student     175
# 3  julie   44      F  scientist     169

# %%
merge_outer = pd.merge(users, user4, on='name', how='outer')
merge_outer
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1  anderson   NaN    NaN        NaN   180.0
# 2      eric  22.0      M    student   175.0
# 3      john  26.0      M    student   180.0
# 4     julie  44.0      F  scientist   169.0
# 5      paul  58.0      F    manager     NaN
# 6     peter  33.0      M   engineer     NaN

# %%
merge_left = pd.merge(users, user4, on='name', how='left')
merge_left
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager     NaN
# 4  peter   33      M   engineer     NaN
# 5  julie   44      F  scientist   169.0

# %%
merge_right = pd.merge(users, user4, on='name', how='left')
merge_right
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager     NaN
# 4  peter   33      M   engineer     NaN
# 5  julie   44      F  scientist   169.0

# %% [markdown]
# ### Summarizing

# %%
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users.head()
# Out:
#     name  age gender       job
# 0  alice   19      F   student
# 1   john   26      M   student
# 2   eric   22      M   student
# 3   paul   58      F   manager
# 4  peter   33      M  engineer

# %%
users.tail()
# Out:
#     name  age gender        job
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users.head(3)
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 2   eric   22      M  student

# %%
users.tail(3)
# Out:
#     name  age gender        job
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users.sample()
# Out:
#     name  age gender      job
# 0  alice   19      F  student

# %%
users.sample(3)
# Out:
#     name  age gender        job
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 5  julie   44      F  scientist

# %%
users.any()
# Out:
# name      True
# age       True
# gender    True
# job       True
# dtype: bool

# %%
print(users.index)
print(users.columns)
print(users.dtypes)
print(type(users.dtypes))
# Out:
# RangeIndex(start=0, stop=6, step=1)
# Index(['name', 'age', 'gender', 'job'], dtype='object')
# name      object
# age        int64
# gender    object
# job       object
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(users.shape)
print(f"So the DataFrame contains {users.shape[0]} rows and {users.shape[1]} columns")
# Out:
# (6, 4)
# So the DataFrame contains 6 rows and 4 columns

# %%
print(users.values)  # dataframe to ndarray
print(users.to_numpy())
print(np.array(users))
print(users.values.ndim, users.values.shape, len(users.values), users.values.size)
# Out:
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# 2 (6, 4) 6 24

# %%
print(users.job.value_counts())
print(users.gender.value_counts())
# Out:
# job
# student      3
# manager      1
# engineer     1
# scientist    1
# Name: count, dtype: int64
# gender
# F    3
# M    3
# Name: count, dtype: int64

# %% [markdown]
# ### Column Selection

# %%
print(users.columns)
print(users.age)
print(users['age'])
print(users[['age', 'name']])
# Out:
# Index(['name', 'age', 'gender', 'job'], dtype='object')
# 0    19
# 1    26
# 2    22
# 3    58
# 4    33
# 5    44
# Name: age, dtype: int64
# 0    19
# 1    26
# 2    22
# 3    58
# 4    33
# 5    44
# Name: age, dtype: int64
#    age   name
# 0   19  alice
# 1   26   john
# 2   22   eric
# 3   58   paul
# 4   33  peter
# 5   44  julie

# %%
users.describe()
# Out:
#              age
# count   6.000000
# mean   33.666667
# std    14.895189
# min    19.000000
# 25%    23.000000
# 50%    29.500000
# 75%    41.250000
# max    58.000000

# %%
users.describe().transpose()
# Out:
#      count       mean        std   min   25%   50%    75%   max
# age    6.0  33.666667  14.895189  19.0  23.0  29.5  41.25  58.0

# %%
users.describe().T
# Out:
#      count       mean        std   min   25%   50%    75%   max
# age    6.0  33.666667  14.895189  19.0  23.0  29.5  41.25  58.0

# %%
users.describe(include='object').T
# Out:
#        count unique      top freq
# name       6      6    alice    1
# gender     6      2        F    3
# job        6      4  student    3

# %%
users.describe(include='all').T
# Out:
#        count unique      top freq       mean        std   min   25%   50%  \
# name       6      6    alice    1        NaN        NaN   NaN   NaN   NaN
# age      6.0    NaN      NaN  NaN  33.666667  14.895189  19.0  23.0  29.5
# gender     6      2        F    3        NaN        NaN   NaN   NaN   NaN
# job        6      4  student    3        NaN        NaN   NaN   NaN   NaN
#
#           75%   max
# name      NaN   NaN
# age     41.25  58.0
# gender    NaN   NaN
# job       NaN   NaN

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   gender  6 non-null      object
#  3   job     6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 324.0+ bytes

# %% [markdown]
# ### Column Selection

# %%
users.age  # single column selection
# Out:
# 0    19
# 1    26
# 2    22
# 3    58
# 4    33
# 5    44
# Name: age, dtype: int64

# %%
users['age']  # single column selection
# Out:
# 0    19
# 1    26
# 2    22
# 3    58
# 4    33
# 5    44
# Name: age, dtype: int64

# %%
users[['age', 'name']]  # multi-column selection
# Out:
#    age   name
# 0   19  alice
# 1   26   john
# 2   22   eric
# 3   58   paul
# 4   33  peter
# 5   44  julie

# %%
print(users.job)
print(users.job.unique(), type(users.job.unique()))
print(np.sort(users.job.unique()))
# Out:
# 0      student
# 1      student
# 2      student
# 3      manager
# 4     engineer
# 5    scientist
# Name: job, dtype: object
# ['student' 'manager' 'engineer' 'scientist'] <class 'numpy.ndarray'>
# ['engineer' 'manager' 'scientist' 'student']

# %% [markdown]
# ### Row Selection

# %%
df = users.copy()
print(df.iloc[3])
print(type(df.iloc[3]))
print(df.loc[3])
print(type(df.loc[3]))

# %%
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print(df.iloc[3][1], df.iloc[3]['age'], df.loc[3][1], df.loc[3]['age'])
print(df.iloc[3, 1], df.iloc[3]['age'], df.loc[3][1], df.loc[3, 'age'])
print(df.size, df.ndim, df.shape, len(df))
print(df.dtypes)

# %%
print(merge_outer.shape, merge_outer.size)

# %%
merge_outer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     6 non-null      float64
#  2   gender  6 non-null      object
#  3   job     6 non-null      object
#  4   height  5 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 412.0+ bytes

# %%
df = users.copy()
df['age'] = df['age'] + 100
df.age = df.age + 100
df.age += 100
df.iloc[:, 1] += 100
df

# %% [markdown]
# ### Row Selection and filtering

# %%
df = users.copy()
df

# %%
print(df.age <= 40)  # boolean series
print(df[df.age <= 40])
print(~(df.age <= 40))
print(df[~(df.age <= 40)])
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: age, dtype: bool
#     name  age gender       job
# 0  alice   19      F   student
# 1   john   26      M   student
# 2   eric   22      M   student
# 4  peter   33      M  engineer
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: age, dtype: bool
#     name  age gender        job
# 3   paul   58      F    manager
# 5  julie   44      F  scientist

# %%
df = users.copy()
# list name, age and job where age <= 40
df[df.age <= 40][['name', 'age', 'gender']]

# %%
df[(df.age <= 40) & (df.gender == 'F')]
# Out:
#     name  age gender      job
# 0  alice   19      F  student

# %%
df[(df.age <= 30) | (df.gender == 'F')]
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 5  julie   44      F  scientist

# %%
df.sort_values(by = 'age', ignore_index=True, ascending=False, inplace=True)

# %%
df
# Out:
#     name  age gender        job
# 0   paul   58      F    manager
# 1  julie   44      F  scientist
# 2  peter   33      M   engineer
# 3   john   26      M    student
# 4   eric   22      M    student
# 5  alice   19      F    student

# %%
df.sort_values(by = ['gender','age'], ignore_index=True, ascending=[True,False], inplace=True)
df
# Out:
#     name  age gender        job
# 0   paul   58      F    manager
# 1  julie   44      F  scientist
# 2  alice   19      F    student
# 3  peter   33      M   engineer
# 4   john   26      M    student
# 5   eric   22      M    student

# %% [markdown]
# ### Unpivot and Pivot Operations

# %%
df = users.copy()
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
stacked = pd.melt(df, id_vars="name", var_name="variable", value_name="value")
stacked
# Out:
#      name variable      value
# 0   alice      age         19
# 1    john      age         26
# 2    eric      age         22
# 3    paul      age         58
# 4   peter      age         33
# 5   julie      age         44
# 6   alice   gender          F
# 7    john   gender          M
# 8    eric   gender          M
# 9    paul   gender          F
# 10  peter   gender          M
# 11  julie   gender          F
# 12  alice      job    student
# 13   john      job    student
# 14   eric      job    student
# 15   paul      job    manager
# 16  peter      job   engineer
# 17  julie      job  scientist

# %%
unstacked = stacked.pivot(index='name', columns='variable', values="value")
unstacked.reset_index(inplace=True)
print(unstacked.columns.name)
unstacked.columns.name = ""
unstacked
# Out:
# variable
#     name age gender        job
# 0  alice  19      F    student
# 1   eric  22      M    student
# 2   john  26      M    student
# 3  julie  44      F  scientist
# 4   paul  58      F    manager
# 5  peter  33      M   engineer

# %% [markdown]
# ### Quality Control: Duplicate Data

# %%
df = users.copy()
df = pd.concat([df, df[df.index == 0]])
df = pd.concat([df, df[df.index == 2]])
df = pd.concat([df, df[df.index == 3]])
df = pd.concat([df, df[df.index == 5]])
print(df.index, df.shape[0])
df.index = range(0, df.shape[0])
df
# Out:
# Index([0, 1, 2, 3, 4, 5, 0, 2, 3, 5], dtype='int64') 10
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist
# 6  alice   19      F    student
# 7   eric   22      M    student
# 8   paul   58      F    manager
# 9  julie   44      F  scientist

# %%
df.sort_values(by = "age", ignore_index=True, inplace=True)
df

# %%
df.duplicated()

# %%
df[df.duplicated()]

# %%
df[~df.duplicated()]

# %%
df.drop_duplicates(inplace=True, ignore_index=True)
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   eric   22      M    student
# 2   john   26      M    student
# 3  peter   33      M   engineer
# 4  julie   44      F  scientist
# 5   paul   58      F    manager

# %% [markdown]
# ### Quality Control: Missing Values

# %%
df = merge_left.copy()
df.sort_values(by=['gender','job'], ascending=True, inplace=True, ignore_index=True)
df
# Out:
#     name  age gender        job  height
# 0   paul   58      F    manager     NaN
# 1  julie   44      F  scientist   169.0
# 2  alice   19      F    student   165.0
# 3  peter   33      M   engineer     NaN
# 4   john   26      M    student   180.0
# 5   eric   22      M    student   175.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   gender  6 non-null      object
#  3   job     6 non-null      object
#  4   height  4 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 372.0+ bytes

# %%
df.isnull()
# Out:
#     name    age  gender    job  height
# 0  False  False   False  False    True
# 1  False  False   False  False   False
# 2  False  False   False  False   False
# 3  False  False   False  False    True
# 4  False  False   False  False   False
# 5  False  False   False  False   False

# %%
df.notnull()
# Out:
#    name   age  gender   job  height
# 0  True  True    True  True   False
# 1  True  True    True  True    True
# 2  True  True    True  True    True
# 3  True  True    True  True   False
# 4  True  True    True  True    True
# 5  True  True    True  True    True

# %%
print(df.height.isnull().sum())
df.height.isnull()
# Out:
# 2
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: height, dtype: bool

# %%
print(df.height.notnull().sum())
df.height.notnull()
# Out:
# 4
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# Name: height, dtype: bool

# %%
# strategy-1 (deleting rows containing null values)
df1 = df.copy()
df1.dropna(inplace = True)
df1
# Out:
#     name  age gender        job  height
# 1  julie   44      F  scientist   169.0
# 2  alice   19      F    student   165.0
# 4   john   26      M    student   180.0
# 5   eric   22      M    student   175.0

# %%
df1 = df.copy()
df1.dropna(how = "all", inplace = True)
df1
# Out:
#     name  age gender        job  height
# 0   paul   58      F    manager     NaN
# 1  julie   44      F  scientist   169.0
# 2  alice   19      F    student   165.0
# 3  peter   33      M   engineer     NaN
# 4   john   26      M    student   180.0
# 5   eric   22      M    student   175.0

# %%
# strategy-2 (filling up null values)
df1 = df.copy()
mean_height = df1.height.mean()
print(mean_height)
df1.fillna(mean_height, inplace = True)
df1
# Out:
# 172.25
#     name  age gender        job  height
# 0   paul   58      F    manager  172.25
# 1  julie   44      F  scientist  169.00
# 2  alice   19      F    student  165.00
# 3  peter   33      M   engineer  172.25
# 4   john   26      M    student  180.00
# 5   eric   22      M    student  175.00

# %%
# forward fill
df1 = df.copy()
df1.fillna(method = 'pad', inplace=True)  # forward fill
df1
# Out:
#     name  age gender        job  height
# 0   paul   58      F    manager     NaN
# 1  julie   44      F  scientist   169.0
# 2  alice   19      F    student   165.0
# 3  peter   33      M   engineer   165.0
# 4   john   26      M    student   180.0
# 5   eric   22      M    student   175.0

# %%
# backward fill
df1 = df.copy()
df1.fillna(method = 'bfill', inplace=True)  # backward fill
df1
# Out:
#     name  age gender        job  height
# 0   paul   58      F    manager   169.0
# 1  julie   44      F  scientist   169.0
# 2  alice   19      F    student   165.0
# 3  peter   33      M   engineer   180.0
# 4   john   26      M    student   180.0
# 5   eric   22      M    student   175.0

# %% [markdown]
# ### Previous Dataframes

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
user_data = [['alice',19,'F','student'],['john',26,'M','student']]
user_columns = ['name','age','gender','job']
user1 = pd.DataFrame(data=user_data, columns=user_columns)
user_data = dict(name=['eric','julie'], age=[22,58], gender=['M','F'], job=['student','manager'])
user2 = pd.DataFrame(data=user_data)
user_data = {'name':['peter','paul'], 'age':[33,44], 'gender':['M','F'], 'job':['engineer','scientist']}
user3 = pd.DataFrame(data=user_data)
users = pd.concat([user1,user2,user3], ignore_index=True)
dict_data = dict(name=['alice','john','eric','julie','andrew'],height=[165,180,175,180,185])
user4 = pd.DataFrame(data=dict_data)
merge_inner = pd.merge(users, user4, on='name', how='inner')
merge_outer = pd.merge(users, user4, on='name', how='outer')
merge_left = pd.merge(users, user4, on='name', how='left')
merge_right = pd.merge(users, user4, on='name', how='right')

# %% [markdown]
# ### Rename Column Names

# %%
df = users.copy()
print(df.columns)
df
# Out:
# Index(['name', 'age', 'gender', 'job'], dtype='object')
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3  julie   58      F    manager
# 4  peter   33      M   engineer
# 5   paul   44      F  scientist

# %%
df = users.copy()
df.columns = ['new_name', 'new_age', 'new_gender', 'new_job']
df
# Out:
#   new_name  new_age new_gender    new_job
# 0    alice       19          F    student
# 1     john       26          M    student
# 2     eric       22          M    student
# 3    julie       58          F    manager
# 4    peter       33          M   engineer
# 5     paul       44          F  scientist

# %%
df = users.copy()
print(df.columns)
df = df.rename(columns = {'name':'new_name', 'age':'new_age', 'gender':'new_gender', 'job':'new_job'})
print(df.columns)
df
# Out:
# Index(['name', 'age', 'gender', 'job'], dtype='object')
# Index(['new_name', 'new_age', 'new_gender', 'new_job'], dtype='object')
#   new_name  new_age new_gender    new_job
# 0    alice       19          F    student
# 1     john       26          M    student
# 2     eric       22          M    student
# 3    julie       58          F    manager
# 4    peter       33          M   engineer
# 5     paul       44          F  scientist

# %%
df = users.copy()
print(df.columns)
df = df.rename(columns = {'name':'new_name', 'gender':'new_gender'})
print(df.columns)
df
# Out:
# Index(['name', 'age', 'gender', 'job'], dtype='object')
# Index(['new_name', 'age', 'new_gender', 'job'], dtype='object')
#   new_name  age new_gender        job
# 0    alice   19          F    student
# 1     john   26          M    student
# 2     eric   22          M    student
# 3    julie   58          F    manager
# 4    peter   33          M   engineer
# 5     paul   44          F  scientist

# %% [markdown]
# ### Groupby on DataFrame

# %%
 df = users.copy()
for group, data_frame in df.groupby('job'):
    print(group, type(group))
    print(type(data_frame))
    print(data_frame)
    print()
# Out:
# engineer <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#     name  age gender       job
# 4  peter   33      M  engineer
#
# manager <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#     name  age gender      job
# 3  julie   58      F  manager
#
# scientist <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#    name  age gender        job
# 5  paul   44      F  scientist
#
# student <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 2   eric   22      M  student

# %%
 df = users.copy()
for group, data_frame in df.groupby('gender'):
    print(group, type(group))
    print(type(data_frame))
    print(data_frame)
    print()
# Out:
# F <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#     name  age gender        job
# 0  alice   19      F    student
# 3  julie   58      F    manager
# 5   paul   44      F  scientist
#
# M <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
#     name  age gender       job
# 1   john   26      M   student
# 2   eric   22      M   student
# 4  peter   33      M  engineer

# %%
df = users.copy()
grouped_df = df.groupby('job').agg({'age':['sum','mean','max','min'], 'gender':['count'], 'job':'count'})
grouped_df
# Out:
#           age                    gender   job
#           sum       mean max min  count count
# job
# engineer   33  33.000000  33  33      1     1
# manager    58  58.000000  58  58      1     1
# scientist  44  44.000000  44  44      1     1
# student    67  22.333333  26  19      3     3

# %%
df = users.copy()
grouped_df = df.groupby('gender').agg({'age':['sum','mean','max','min'], 'gender':['count'], 'job':'count'})
grouped_df
# Out:
#         age                    gender   job
#         sum       mean max min  count count
# gender
# F       121  40.333333  58  19      3     3
# M        81  27.000000  33  22      3     3

# %% [markdown]
# ### Reading data from external sources

# %%
try:
    print("Reading .CSV file content...")
    # df = pd.read_csv("salary_table.csv")
    # df = pd.read_csv("./salary_table.csv")
    # df = pd.read_csv("C:\\Users\\arnab\\SVGI-Data-Science-Batch-1\\salary_table.csv")
    # df = pd.read_csv("C://Users//arnab//SVGI-Data-Science-Batch-1//salary_table.csv")
    # df = pd.read_csv("C:/Users/arnab/SVGI-Data-Science-Batch-1/salary_table.csv")
    # df = pd.read_csv("C://Users\\arnab/SVGI-Data-Science-Batch-1//salary_table.csv")
    df = pd.read_csv("https://raw.githubusercontent.com/toarnabtrainer/SVGI-Data-Science-Course-Batch-1/refs/heads/main/Datafile/salary_table.csv")
    print(df.head())
except:
    print("File access error...!!!")
    print("Data file could not be read successfully...")
# Out:
# Reading .CSV file content...
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
try:
    print("Reading .CSV file content...")
    # df = pd.read_csv("salary_table.csv")
    # df = pd.read_csv("./salary_table.csv")
    # df = pd.read_csv("C:\\Users\\arnab\\SVGI-Data-Science-Batch-1\\salary_table.csv")
    # df = pd.read_csv("C://Users//arnab//SVGI-Data-Science-Batch-1//salary_table.csv")
    # df = pd.read_csv("C:/Users/arnab/SVGI-Data-Science-Batch-1/salary_table.csv")
    # df = pd.read_csv("C://Users\\arnab/SVGI-Data-Science-Batch-1//salary_table.csv")
    df = pd.read_csv("https://raw.githubusercontent.com/toarnabtrainer/SVGI-Data-Science-Course-Batch-1/refs/heads/main/Datafile/salary_table.csv")
    print(df.head())
except:
    print("File access error...!!!")
    print("Data file could not be read successfully...")
# Out:
# Reading .CSV file content...
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %% [markdown]
# ### Accessing files in Colab

# %%
# reading external file in colab notebook
# strategy - 1
from google.colab import files
uploaded = files.upload()

# %%
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['salary_table.csv']))
df.head()

# %%
# strategy - 2
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/salary_table.csv")
df.head()

# %%
# strategy - 3
df = pd.read_csv("/content/salary_table.csv")
df.head()

# %% [markdown]
# ### Reading MS-Excel workbook data onto the data frame

# %%
pd.options.display.width = 500
try:
    print("Reading data from .XLSX file...")
    df = pd.read_excel("./Online Retail.xlsx")
    print(df.head())
except:
    print("File access error...!!!")
    print("Data file could not be read successfully...")
# Out:
# Reading data from .XLSX file...
#    INVOICENO STOCKCODE                          DESCRIPTION  QUANTITY         INVOICEDATE  UNITPRICE  CUSTOMERID         COUNTRY
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1     536365     71053                  WHITE METAL LANTERN         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4     536403     22867              HAND WARMER BIRD DESIGN        96 2010-12-01 11:27:00       1.85       12791     Netherlands

# %% [markdown]
# ### Insert, Delete and Replace Column Values

# %%
df1 = df.copy()
df1.head()
# Out:
#    INVOICENO STOCKCODE                          DESCRIPTION  QUANTITY         INVOICEDATE  UNITPRICE  CUSTOMERID         COUNTRY
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1     536365     71053                  WHITE METAL LANTERN         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4     536403     22867              HAND WARMER BIRD DESIGN        96 2010-12-01 11:27:00       1.85       12791     Netherlands

# %%
df1 = df1[["INVOICENO", "UNITPRICE", "CUSTOMERID", "COUNTRY"]]
df1.head()
# Out:
#    INVOICENO  UNITPRICE  CUSTOMERID         COUNTRY
# 0     536365       2.55       17850  United Kingdom
# 1     536365       3.39       17850  United Kingdom
# 2     536365       2.75       17850  United Kingdom
# 3     536365       3.39       17850  United Kingdom
# 4     536403       1.85       12791     Netherlands

# %%
# insert a column
df1.insert(2, 'TAX', df1.UNITPRICE * 0.10)
df1.head()
# Out:
#    INVOICENO  UNITPRICE    TAX  CUSTOMERID         COUNTRY
# 0     536365       2.55  0.255       17850  United Kingdom
# 1     536365       3.39  0.339       17850  United Kingdom
# 2     536365       2.75  0.275       17850  United Kingdom
# 3     536365       3.39  0.339       17850  United Kingdom
# 4     536403       1.85  0.185       12791     Netherlands

# %%
# delete a column
df2 = df1.copy()
df2.drop("INVOICENO", axis = 1, inplace = True)
df2.head()
# Out:
#    UNITPRICE    TAX  CUSTOMERID         COUNTRY
# 0       2.55  0.255       17850  United Kingdom
# 1       3.39  0.339       17850  United Kingdom
# 2       2.75  0.275       17850  United Kingdom
# 3       3.39  0.339       17850  United Kingdom
# 4       1.85  0.185       12791     Netherlands

# %%
# replacing COUNTRY column values
df3 = df2.copy()
print(df3.COUNTRY)
# Out:
# 0     United Kingdom
# 1     United Kingdom
# 2     United Kingdom
# 3     United Kingdom
# 4        Netherlands
# 5        Netherlands
# 6          Australia
# 7          Australia
# 8          Australia
# 9          Australia
# 10            France
# 11            France
# 12            France
# 13            France
# 14           Germany
# Name: COUNTRY, dtype: object

# %%
df3.COUNTRY.replace({"France":"Fr", "United Kingdom":"UK", "Netherlands":"Ned", "Australia":"Aus", "Germany":"Gr"}, inplace=True)
df3
# Out:
#     UNITPRICE    TAX  CUSTOMERID COUNTRY
# 0        2.55  0.255       17850      UK
# 1        3.39  0.339       17850      UK
# 2        2.75  0.275       17850      UK
# 3        3.39  0.339       17850      UK
# 4        1.85  0.185       12791     Ned
# 5       15.00  1.500       12791     Ned
# 6        8.50  0.850       12431     Aus
# 7        4.95  0.495       12431     Aus
# 8        1.25  0.125       12431     Aus
# 9        5.45  0.545       12431     Aus
# 10       3.75  0.375       12583      Fr
# 11       3.75  0.375       12583      Fr
# 12       1.25  0.125       12583      Fr
# 13       2.95  0.295       12583      Fr
# 14      18.00  1.800       12662      Gr

# %%
df3["COUNTRY"].replace(["Fr", "UK", "Ned", "Aus", "Gr"], ["France", "United Kingdom", "Netherlands", "Australia", "Germany"], inplace=True)
df3
# Out:
#     UNITPRICE    TAX  CUSTOMERID         COUNTRY
# 0        2.55  0.255       17850  United Kingdom
# 1        3.39  0.339       17850  United Kingdom
# 2        2.75  0.275       17850  United Kingdom
# 3        3.39  0.339       17850  United Kingdom
# 4        1.85  0.185       12791     Netherlands
# 5       15.00  1.500       12791     Netherlands
# 6        8.50  0.850       12431       Australia
# 7        4.95  0.495       12431       Australia
# 8        1.25  0.125       12431       Australia
# 9        5.45  0.545       12431       Australia
# 10       3.75  0.375       12583          France
# 11       3.75  0.375       12583          France
# 12       1.25  0.125       12583          France
# 13       2.95  0.295       12583          France
# 14      18.00  1.800       12662         Germany

# %%
# factorizing COUNTRY column values
df3.insert(4, "COUNTRY_CODE", pd.factorize(df3['COUNTRY'])[0])
df3
# Out:
#     UNITPRICE    TAX  CUSTOMERID         COUNTRY  COUNTRY_CODE
# 0        2.55  0.255       17850  United Kingdom             0
# 1        3.39  0.339       17850  United Kingdom             0
# 2        2.75  0.275       17850  United Kingdom             0
# 3        3.39  0.339       17850  United Kingdom             0
# 4        1.85  0.185       12791     Netherlands             1
# 5       15.00  1.500       12791     Netherlands             1
# 6        8.50  0.850       12431       Australia             2
# 7        4.95  0.495       12431       Australia             2
# 8        1.25  0.125       12431       Australia             2
# 9        5.45  0.545       12431       Australia             2
# 10       3.75  0.375       12583          France             3
# 11       3.75  0.375       12583          France             3
# 12       1.25  0.125       12583          France             3
# 13       2.95  0.295       12583          France             3
# ...

# %% [markdown]
# ### Data Visualization with Data Frame

# %%
df = pd.read_csv("salary_table.csv")
print(df.shape)
df.head()
# Out:
# (46, 4)
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
df.describe().T
# Out:
#             count          mean          std      min       25%      50%       75%      max
# salary       46.0  17270.195652  4716.631513  10535.0  13320.75  16436.0  20719.75  27837.0
# experience   46.0      7.500000     5.171503      1.0      3.00      6.0     11.00     20.0

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.experience.plot()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.experience.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.experience.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.experience.plot.line()
# Out:
# <Axes: >

# %%
df.salary.head(10).plot.pie()
# Out:
# <Axes: ylabel='salary'>

# %%
df.salary.head(10).plot.pie(autopct = "%.2f")
# Out:
# <Axes: ylabel='salary'>

# %%
df["salary"].plot.box()
# Out:
# <Axes: >

# %%
df.experience.plot.box()
# Out:
# <Axes: >

# %%
df.plot(kind = "scatter", x = "experience", y = "salary", s = 40, title = "Experience in Years vs. Salary in INR")
# Out:
# <Axes: title={'center': 'Experience in Years vs. Salary in INR'}, xlabel='experience', ylabel='salary'>
